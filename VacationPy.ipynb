# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import matplotlib.pyplot as plt



# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1004'>
#   <div id="b09833de-7790-415a-bd10-6a35906aef96" data-root-id="p1004" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5f16728a-1a51-4241-b2fe-67f516a37844":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1004"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1005","attributes":{"plot_id":"p1004","comm_id":"56af770b82b74544816b5547248ec2d2","client_comm_id":"397779e3485240f89f257b6cc1a0006c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"5f16728a-1a51-4241-b2fe-67f516a37844","roots":{"p1004":"b09833de-7790-415a-bd10-6a35906aef96"},"root_ids":["p1004"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat      Lng  Max Temp  Humidity  \
# 0        0                       igarka  67.4667  86.5833    252.39        91
# 1        1                      talnakh  69.4865  88.3972    245.08        91
# 2        2  edinburgh of the seven seas -37.0676 -12.3116    286.12        81
# 3        3                  west island -12.1568  96.8225    300.14        83
# 4        4                      aasiaat  68.7098 -52.8699    269.96        77
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        5.25      RU  1731348836
# 1          29        0.76      RU  1731348837
# 2          99        7.58      SH  1731348838
# 3         100        5.66      CC  1731348839
# 4         100        4.27      GL  1731348840

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",   
    color = "City"
)

# Display the map
map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# Define ideal weather conditions
ideal_weather_df = city_data_df[
    (city_data_df["Max Temp"] >= 290) & (city_data_df["Max Temp"] <= 300) &
    (city_data_df["Humidity"] < 60) &
    (city_data_df["Cloudiness"] < 30) &
    (city_data_df["Wind Speed"] < 5)
]

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display sample data
ideal_weather_df
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 47        47                   tataouine  32.9297   10.4518    293.55
# 54        54                    coquimbo -29.9533  -71.3436    292.03
# 79        79                    azamgarh  26.0600   83.1861    297.36
# 109      109                      at taj  24.2049   23.2857    292.14
# 131      131                    al hufuf  25.3646   49.5653    298.34
# 157      157            kot radha kishan  31.1725   74.0997    295.16
# 165      165                      bechar  31.6167   -2.2167    292.60
# 174      174                   iranshahr  27.2025   60.6848    296.85
# 195      195                  as safirah  36.0770   37.3725    291.23
# 223      223                     ar rass  25.8694   43.4973    298.60
# 227      227                       crane  31.3974 -102.3501    294.65
# 249      249                al mutayrifi  25.4788   49.5576    298.34
# 265      265                 tamanrasset  22.7850    5.5228    294.10
# 319      319                    ad dilam  23.9915   47.1627    298.01
# 369      369                         una  20.8167   71.0333    298.04
# 372      372                    rouissat  31.9243    5.3502    293.22
# 380      380                   aman garh  34.0058   71.9300    294.14
# 391      391                       deoli  25.7500   75.3833    296.84
# 445      445                    qaisumah  28.3112   46.1273    297.13
# 478      478                       paoua   7.2427   16.4406    297.23
# 484      484                      robbah  33.2797    6.9098    294.47
# 508      508                  isla vista  34.4133 -119.8610    293.90
# 530      530                  san julian  21.0167 -102.1667    298.14
# 542      542                 deir ez-zor  35.3359   40.1408    292.13
# 554      554  san sebastian de la gomera  28.0916  -17.1133    298.35
# 559      559                 sao vicente -23.9631  -46.3919    298.14
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 47         55          23        2.37      TN  1731348889
# 54         55           0        4.83      CL  1731348897
# 79         46           0        1.85      IN  1731348926
# 109        29           0        3.49      LY  1731348960
# 131        41           0        0.00      SA  1731348985
# 157        42           0        2.92      PK  1731349018
# 165        34           0        2.18      DZ  1731349027
# 174        24           6        2.02      IR  1731349038
# 195        41          18        2.56      SY  1731349063
# 223        27           2        3.88      SA  1731349095
# 227        26          29        2.41      US  1731349100
# 249        52           4        1.79      SA  1731349126
# 265        21           0        3.09      DZ  1731349145
# 319        31           1        3.09      SA  1731349207
# 369        43           0        2.56      IN  1731349268
# 372        44           0        1.73      DZ  1731349271
# 380        50           0        1.52      PK  1731349280
# 391        28          14        1.42      IN  1731349292
# 445        43           0        2.57      SA  1731349354
# 478        46           3        1.02      CF  1731349392
# 484        47           5        0.48      DZ  1731349399
# 508        56          25        2.24      US  1731349285
# 530        27          20        4.12      MX  1731349453
# 542        47           0        2.96      SY  1731349466
# 554        57           0        2.06      ES  1731349480
# 559        26           2        2.79      BR  1731349364

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Assuming city_data_df is already defined
hotel_df = city_data_df.copy()  # Create a copy of city_data_df
hotel_df['Hotel name'] = ''  # Add an empty column 'Hotel name'
hotel_df = hotel_df.reset_index(drop=True) 


# Display the first few rows of the new DataFrame
hotel_df.head()
# Out:
#    City_ID                         City      Lat      Lng  Max Temp  Humidity  \
# 0        0                       igarka  67.4667  86.5833    252.39        91
# 1        1                      talnakh  69.4865  88.3972    245.08        91
# 2        2  edinburgh of the seven seas -37.0676 -12.3116    286.12        81
# 3        3                  west island -12.1568  96.8225    300.14        83
# 4        4                      aasiaat  68.7098 -52.8699    269.96        77
#
#    Cloudiness  Wind Speed Country        Date Hotel name
# 0         100        5.25      RU  1731348836
# 1          29        0.76      RU  1731348837
# 2          99        7.58      SH  1731348838
# 3         100        5.66      CC  1731348839
# 4         100        4.27      GL  1731348840

# %%
import pandas as pd

# Sample data for city_data_df
data = {
    "City": ["igarka", "talnakh", "edinburgh of the seven seas", "west island", "aasiaat"],
    "Country": ["RU", "RU", "SH", "CC", "GL"],
    "Lat": [67.4667, 69.4865, -37.0676, -12.1568, 68.7098],
    "Lng": [86.5833, 88.3972, -12.3116, 96.8225, -52.8699],
    "Humidity": [91, 91, 81, 83, 77]
}

# Create hotel_df DataFrame with specified columns and add empty "Hotel Name" column
hotel_df = pd.DataFrame(data)
hotel_df["Hotel Name"] = ""

# Display the sample data of hotel_df
hotel_df

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000  # 10,000 meters = 10 kilometers

# Define the parameters for the Geoapify API request
params = {
    'categories': 'accommodation.hotel',  # Only look for hotels
    'limit': 1,  # Limit to the first hotel found
    'apiKey': geoapify_key  # Your Geoapify API key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from the DataFrame
    lat = row['Lat']  # Assuming the latitude column is named 'latitude'
    lon = row['Lng']  # Assuming the longitude column is named 'longitude'

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lon},{lat},{radius}'  # Define the search area
    params["bias"] = f'proximity:{lon},{lat}'  # Use the coordinates as the bias for search

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)
    name_address = response.json()
    # Convert the API response to JSON format
    try:
                # Grab the first hotel from the results and store the name in the hotel_df DataFrame
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
# Display sample data
hotel_df
# Out:
# Starting hotel search
# igarka - nearest hotel: Заполярье
# talnakh - nearest hotel: Талнах
# edinburgh of the seven seas - nearest hotel: No hotel found
# west island - nearest hotel: Cocos Village Bungalows
# aasiaat - nearest hotel: SØMA
# georgetown - nearest hotel: Page 63 hostel
# adamstown - nearest hotel: No hotel found
# myeik - nearest hotel: Green Eyes Hotel
# yauya - nearest hotel: No hotel found
# uturoa - nearest hotel: Hawaiki Nui hotel
# batticaloa - nearest hotel: Lake View Hotel
# kievka - nearest hotel: No hotel found
# albany - nearest hotel: No hotel found
# waitangi - nearest hotel: Hotel Chathams
# akureyri - nearest hotel: Hótel Norðurland
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# longyearbyen - nearest hotel: The Vault
# hawaiian paradise park - nearest hotel: No hotel found
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# goure - nearest hotel: No hotel found
# anadyr - nearest hotel: Гостевой дом
# grytviken - nearest hotel: No hotel found
# lappeenranta - nearest hotel: Sokos Hotel Lappee
# tiksi - nearest hotel: Арктика
# la'ie - nearest hotel: No hotel found
# north haven - nearest hotel: No hotel found
# buala - nearest hotel: No hotel found
# port-aux-francais - nearest hotel: Keravel
# walvis bay - nearest hotel: Atlantic
# kununurra - nearest hotel: No hotel found
# papatowai - nearest hotel: No hotel found
# kasongo-lunda - nearest hotel: No hotel found
# bethel - nearest hotel: Hampton Inn Danbury
# kalevala - nearest hotel: Отель "ВелТ"
# majene - nearest hotel: RedDoorz @ Hotel Grand Aulia Majene
# port elizabeth - nearest hotel: Waterford Hotel
# cockburn town - nearest hotel: The Salt Raker Inn
# alice springs - nearest hotel: Aurora Alice Springs
# ust-nera - nearest hotel: гостиница "Солнечная"
# lengshuitan - nearest hotel: 华盐大酒店
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# sopur - nearest hotel: No hotel found
# st. john's - nearest hotel: Alt Hotel
# severo-yeniseyskiy - nearest hotel: Актолик
# kamensk-ural'skiy - nearest hotel: Октябрь
# igurusi - nearest hotel: E&S Lodge
# manta - nearest hotel: Hotel Santa Fe
# tataouine - nearest hotel: No hotel found
# keflavik - nearest hotel: Núpan Deluxe
# margaret river - nearest hotel: Margaret River Hotel
# thompson - nearest hotel: Thompson Inn
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# leitchfield - nearest hotel: Hatfield Inn
# selfoss - nearest hotel: Miðgarður
# coquimbo - nearest hotel: Hotel Iberia
# hithadhoo - nearest hotel: Pebbles Inn
# susuman - nearest hotel: No hotel found
# pirai do sul - nearest hotel: No hotel found
# stanley - nearest hotel: Hotel 52
# obligado - nearest hotel: Hotel Real
# port sudan - nearest hotel: Ranya Hotel
# vadso - nearest hotel: Scandic Vadsø
# north lakhimpur - nearest hotel: Hote Majestic Palace
# ketchikan - nearest hotel: Cape Fox Lodge
# iskateley - nearest hotel: Авантаж
# hamilton - nearest hotel: North Vista Manor
# chui - nearest hotel: Alerces
# la passe - nearest hotel: L'Estuaire
# luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# kenora - nearest hotel: Travelodge
# enoch - nearest hotel: Travelodge Cedar City
# phan rang-thap cham - nearest hotel: Khách Sạn Ninh Thuận
# palikir - national government center - nearest hotel: Mangrove Bay Hotel
# iqaluit - nearest hotel: Frobisher Inn
# kunashak - nearest hotel: No hotel found
# nuuk - nearest hotel: Nordbo
# vorgashor - nearest hotel: София
# soto la marina - nearest hotel: Arellano
# patong - nearest hotel: Thara Patong Beach Resort & Spa
# azamgarh - nearest hotel: No hotel found
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# chibougamau - nearest hotel: No hotel found
# rabo de peixe - nearest hotel: Pico do Refugio
# afaahiti - nearest hotel: Omati Lodge
# port mathurin - nearest hotel: Escale Vacances
# tosontsengel - nearest hotel: Алтай
# guerrero negro - nearest hotel: Plaza sal paraiso
# invercargill - nearest hotel: The Grand
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# sinabang - nearest hotel: No hotel found
# isafjordur - nearest hotel: Hótel Horn
# kolonia - nearest hotel: Wasserturm Hotel Cologne
# san fernando de apure - nearest hotel: Hotel Plaza
# lihue - nearest hotel: Kauai Palms
# sao raimundo nonato - nearest hotel: Pousada Lelinha
# trapani - nearest hotel: No hotel found
# ceeldheer - nearest hotel: No hotel found
# tralee - nearest hotel: The Ashe Hotel
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# nabulao - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# klyuchi - nearest hotel: No hotel found
# fu'an - nearest hotel: No hotel found
# tazovsky - nearest hotel: Тазовчанка
# tura - nearest hotel: Hotel Polo Orchid
# belyy yar - nearest hotel: No hotel found
# sao raimundo das mangabeiras - nearest hotel: No hotel found
# avarua - nearest hotel: Paradise Inn
# cururupu - nearest hotel: No hotel found
# at taj - nearest hotel: No hotel found
# mangrol - nearest hotel: No hotel found
# hermanus - nearest hotel: Aloe guest house
# porto tolle - nearest hotel: albergo Italia
# san juan de miraflores - nearest hotel: Venue Hospedaje
# yelets - nearest hotel: Мини-отель Винтаж
# ad darb - nearest hotel: No hotel found
# kuruman - nearest hotel: Palermo Inn
# yuzhno-kurilsk - nearest hotel: Айсберг
# blackmans bay - nearest hotel: Villa Howden
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# bengkulu - nearest hotel: Dena Hotel
# brisas de zicatela - nearest hotel: Casa de Olas
# udachny - nearest hotel: Вилюй
# murghob - nearest hotel: Pamir Hotel
# petawawa - nearest hotel: Quality Inn & Suites
# amble - nearest hotel: Sun Hotel
# papao - nearest hotel: Hiti Moana Villa Lodge
# whitby - nearest hotel: Resolution Hotel
# cedar city - nearest hotel: Baymont Inn & Suites
# kodiak - nearest hotel: No hotel found
# shush - nearest hotel: هتل آپادانا
# al hufuf - nearest hotel: Al Muhaidab Residence Al Ahsa
# franceville - nearest hotel: Hotel Masuku
# kingscliff - nearest hotel: Kingscliff Beach Hotel
# la ronge - nearest hotel: La Ronge Hotel and Suites
# minas de marcona - nearest hotel: No hotel found
# ola - nearest hotel: No hotel found
# harstad - nearest hotel: Scandic Harstad
# saint-francois - nearest hotel: Chez Lily
# broken hill - nearest hotel: Ibis Styles
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# blackwater - nearest hotel: No hotel found
# cole harbour - nearest hotel: Hearthstone Inn Boutique Hotel Dartmouth/Halifax
# mirny - nearest hotel: Зарница
# punta arenas - nearest hotel: Hotel Lacolet
# al jawf - nearest hotel: No hotel found
# badger - nearest hotel: Clarion Hotel & Suites
# miyako - nearest hotel: ビックウェーブ
# bilibino - nearest hotel: No hotel found
# hasaki - nearest hotel: Choshi Plaza Hotel
# saudarkrokur - nearest hotel: Mikligarður
# mangai - nearest hotel: No hotel found
# kyren - nearest hotel: No hotel found
# rio grande - nearest hotel: Hotel Vila Moura Executivo
# tsiombe - nearest hotel: No hotel found
# kapuskasing - nearest hotel: Travelodge
# kot radha kishan - nearest hotel: No hotel found
# garissa - nearest hotel: Hiddig Hotel
# qamdo - nearest hotel: 银杏商务宾馆
# bredasdorp - nearest hotel: Victoria Hotel
# paphos - nearest hotel: Mayfair Gardens Hotel
# yellowknife - nearest hotel: No hotel found
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# codrington - nearest hotel: No hotel found
# bechar - nearest hotel: Hôtel Madania
# gambiran satu - nearest hotel: Hotel Grand Royal
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# enumclaw - nearest hotel: Guest House Inn - Enumclaw
# kapa'a - nearest hotel: Pono Kai Resort
# ndele - nearest hotel: No hotel found
# whitehorse - nearest hotel: Town & Mountain Hotel
# salekhard - nearest hotel: No hotel found
# ebaye - nearest hotel: No hotel found
# iranshahr - nearest hotel: هتل قصِر
# bucerias - nearest hotel: Grand Decameron Complex, A Trademark All Inclusive
# garachico - nearest hotel: Residencia El Drago
# atafu village - nearest hotel: No hotel found
# tangalle - nearest hotel: Coco Tangalla
# lompoc - nearest hotel: Red Roof Inn Lompoc
# chernyshevskiy - nearest hotel: No hotel found
# enewetak - nearest hotel: No hotel found
# vologda - nearest hotel: Гостиница Правительства Области
# tolanaro - nearest hotel: Hôtel Mahavokey
# tazacorte - nearest hotel: App Leyma
# willowmore - nearest hotel: No hotel found
# olonkinbyen - nearest hotel: No hotel found
# motygino - nearest hotel: No hotel found
# timaru - nearest hotel: The Grosvenor Hotel
# hilton head island - nearest hotel: Ramada Hilton Head
# coria - nearest hotel: Los Kekes
# chinde - nearest hotel: No hotel found
# kudahuvadhoo - nearest hotel: Hotel Riu Palace Maldivas
# fisterra - nearest hotel: Hotel Temático do Banco Azul
# melipilla - nearest hotel: Las Torres
# as safirah - nearest hotel: No hotel found
# sitka - nearest hotel: Aspen Suites Hotel
# nova sintra - nearest hotel: Residência Ka Dencho
# freetown - nearest hotel: Formal Leona hotel
# olinda - nearest hotel: Fidji Motel
# vyazemskiy - nearest hotel: Гостиница
# utrik - nearest hotel: No hotel found
# orvieto - nearest hotel: Hotel Royal
# el abiodh sidi cheikh - nearest hotel: No hotel found
# inhambane - nearest hotel: Hotel de Inhambane
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# retreat - nearest hotel: No hotel found
# baotou - nearest hotel: 包头宾馆
# magadan - nearest hotel: Гостиница «ВМ-Центр»
# roses - nearest hotel: Ramblamar
# berezovyy - nearest hotel: No hotel found
# lib - nearest hotel: No hotel found
# greymouth - nearest hotel: Recreation Hotel
# mayqayyng - nearest hotel: No hotel found
# alto barinas - nearest hotel: Hotel Turístico Varyná
# maceio - nearest hotel: Maceió Hostel e Pousada
# nadi - nearest hotel: President Hotel
# mokhsogollokh - nearest hotel: No hotel found
# misratah - nearest hotel: الفندق السياحى
# qaqortoq - nearest hotel: Hotel Qaqortoq
# labytnangi - nearest hotel: Семь лиственниц
# carnarvon - nearest hotel: No hotel found
# nicoya - nearest hotel: Hotel marianela
# ar rass - nearest hotel: Saif Boutique Hotel International
# karratha - nearest hotel: Karratha International Hotel
# ongjin - nearest hotel: No hotel found
# kuala belait - nearest hotel: Hotel Sentosa
# crane - nearest hotel: No hotel found
# beloyarskiy - nearest hotel: Сибирь
# akobo - nearest hotel: Owu Crown Hotel
# chiredzi - nearest hotel: Nesbitt Arms Hotel
# tonsberg - nearest hotel: Thon Hotel Tønsberg Brygge
# galliano - nearest hotel: Fairfield Inn & Suites Cut Off-Galliano
# nizhniy odes - nearest hotel: No hotel found
# redwood city - nearest hotel: Best Western
# pangody - nearest hotel: Газпром энерго
# wilmington island - nearest hotel: No hotel found
# weno - nearest hotel: High Tide Hotel
# gustavsberg - nearest hotel: Blå Blom
# constantia - nearest hotel: Hotel Dali
# gadzhiyevo - nearest hotel: Оазис
# ust-tsilma - nearest hotel: Прасковья
# ladario - nearest hotel: Hotel Rios
# tupelo - nearest hotel: Hilton Garden Inn Tupelo
# brotton - nearest hotel: Hunley Hotel & Golf Club
# peterhead - nearest hotel: Albert Hotel
# slaton - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# san patricio - nearest hotel: No hotel found
# al mutayrifi - nearest hotel: No hotel found
# san antonio de pale - nearest hotel: No hotel found
# harper - nearest hotel: No hotel found
# yantarnyy - nearest hotel: Шлосс
# ghat - nearest hotel: فندق تاسيلي
# jamestown - nearest hotel: DoubleTree Jamestown
# conde - nearest hotel: Paladino
# castillos - nearest hotel: A mi gente
# benoy-yurt - nearest hotel: No hotel found
# la punta - nearest hotel: La Posada de Salim
# biloela - nearest hotel: Settlers Hotel Motel
# wenchang - nearest hotel: No hotel found
# nanao - nearest hotel: ホテル・アルファ－ワン能登和倉
# kauhajoki - nearest hotel: Kauhajoen Krouvi
# sola - nearest hotel: No hotel found
# daru - nearest hotel: Kuki
# tamanrasset - nearest hotel: فندق الأمان
# taquari - nearest hotel: No hotel found
# port macquarie - nearest hotel: The Observatory
# mil'kovo - nearest hotel: Дрозды
# kangding - nearest hotel: 溜溜城格桑花大酒店
# kiunga - nearest hotel: No hotel found
# aykhal - nearest hotel: Уют
# lugovoy - nearest hotel: No hotel found
# antigonish - nearest hotel: Microtel Hotel
# emerald - nearest hotel: Emerald Central Hotel
# ancud - nearest hotel: Cabañas
# watertown - nearest hotel: Four Points by Sheraton
# ujae - nearest hotel: No hotel found
# ad dabbah - nearest hotel: No hotel found
# mando - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
# andergrove - nearest hotel: No hotel found
# shiyan - nearest hotel: 汉庭酒店
# brookings - nearest hotel: Quality Inn
# palmer - nearest hotel: No hotel found
# sabang - nearest hotel: Sabang Hill
# pout - nearest hotel: Le Figuier
# gokwe - nearest hotel: No hotel found
# suva - nearest hotel: Extension 68
# dargecit - nearest hotel: Huzur Apart Otel
# kuching - nearest hotel: Hotel Samudera
# dudinka - nearest hotel: Виктория
# christchurch - nearest hotel: Ibis Hotel Christchurch
# hadibu - nearest hotel: No hotel found
# anseong - nearest hotel: No hotel found
# pandan - nearest hotel: No hotel found
# dongning - nearest hotel: No hotel found
# brak - nearest hotel: فندق براك السياحي
# viedma - nearest hotel: Níjar
# bonthe - nearest hotel: No hotel found
# eyl - nearest hotel: فندق ايل دابي
# villa el carmen - nearest hotel: No hotel found
# fish town - nearest hotel: No hotel found
# stornoway - nearest hotel: County Hotel
# rabaul - nearest hotel: Rabaul Hotel
# rikaze - nearest hotel: Gesar Hotel
# litchfield - nearest hotel: No hotel found
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# alofi - nearest hotel: Matavai Resort
# itoman - nearest hotel: No hotel found
# ambovombe - nearest hotel: No hotel found
# queenstown - nearest hotel: Queens Hotel
# huotong - nearest hotel: No hotel found
# poronaysk - nearest hotel: No hotel found
# portland - nearest hotel: the Hoxton
# dul'durga - nearest hotel: No hotel found
# rawson - nearest hotel: Hotel Deportivo
# koper - nearest hotel: Hotel Koper
# viitasaari - nearest hotel: No hotel found
# ad dilam - nearest hotel: No hotel found
# huanta - nearest hotel: Hotel Imperial
# trenton - nearest hotel: Lafayette Park Hotel
# shawinigan - nearest hotel: Hôtel Énergie Shawinigan
# lepsy - nearest hotel: Orley
# cannonvale - nearest hotel: Whitsundays Rainforest Retreat
# saurimo - nearest hotel: Hotel Princesinha
# oltinko'l - nearest hotel: No hotel found
# chiknayakanhalli - nearest hotel: No hotel found
# geraldton - nearest hotel: Ocean Centre Hotel
# leava - nearest hotel: Fia fia
# thinadhoo - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# gorom-gorom - nearest hotel: No hotel found
# sydney mines - nearest hotel: No hotel found
# leer - nearest hotel: Hotel Hafenspeicher
# sheridan - nearest hotel: Comfort Inn & Suites
# umirim - nearest hotel: No hotel found
# wuchuan - nearest hotel: No hotel found
# sur - nearest hotel: Sur Hotel
# richards bay - nearest hotel: SUN1 Richards Bay
# kalachinsk - nearest hotel: No hotel found
# mabaruma - nearest hotel: Hotel Broost
# jiquilpan de juarez - nearest hotel: Palmira
# lebu - nearest hotel: No hotel found
# fuglafjordur - nearest hotel: No hotel found
# pariaman - nearest hotel: HOTEL NAN TONGGA
# altamirano - nearest hotel: Hotel Alcatraces
# kayangel - nearest hotel: No hotel found
# tvoroyri - nearest hotel: Hotel Tvøroyri
# holualoa - nearest hotel: Kona Hotel
# khanty-mansiysk - nearest hotel: Гамма
# vernon - nearest hotel: Okanagan Royal Park Inn
# praia da vitoria - nearest hotel: Salles
# kualakapuas - nearest hotel: Hotel Bayu
# manismata - nearest hotel: No hotel found
# nishinoomote - nearest hotel: ゼウスハウス
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# colonia - nearest hotel: Wasserturm Hotel Cologne
# talcahuano - nearest hotel: Club Recreativo Armada de Chile
# yeniseysk - nearest hotel: Отель Енисейский
# mineiros - nearest hotel: Hotel Dallas
# kamina - nearest hotel: Hôtel DG
# tabou - nearest hotel: hôtel le rochet
# lata - nearest hotel: Residencial Botânico
# talara - nearest hotel: Hospedaje El Aypate
# san jeronimo de juarez - nearest hotel: No hotel found
# douentza - nearest hotel: No hotel found
# chegdomyn - nearest hotel: Бурея
# arkhangel'sk - nearest hotel: Серафима
# una - nearest hotel: No hotel found
# naze - nearest hotel: ビジネス旅館畠山
# mentekab - nearest hotel: Jelai Hotel
# rouissat - nearest hotel: فندق الأروي الذهبي
# chonchi - nearest hotel: Hotel Huildín
# ta`u - nearest hotel: No hotel found
# manggar - nearest hotel: No hotel found
# belle chasse - nearest hotel: Best Western Plus Westbank
# kuacjok - nearest hotel: No hotel found
# cold springs - nearest hotel: No hotel found
# guayaramerin - nearest hotel: Hotel K d' Oro
# aman garh - nearest hotel: No hotel found
# buulobarde - nearest hotel: No hotel found
# el fuerte - nearest hotel: Hotel Haciencda Santa Cruz
# vrangel' - nearest hotel: No hotel found
# diamantino - nearest hotel: Hotel kayaby
# vilyuysk - nearest hotel: Мария
# mount pearl - nearest hotel: Sandman Signature St. John's Hotel
# coahuayana de hidalgo - nearest hotel: No hotel found
# makokou - nearest hotel: Motel des voyageurs
# tromso - nearest hotel: Clarion Collection Hotel Aurora
# kingston - nearest hotel: Aphrodite Hotel
# deoli - nearest hotel: No hotel found
# changji - nearest hotel: No hotel found
# fortaleza - nearest hotel: Hotel Catedral
# ribeira grande - nearest hotel: Hospedaria JSF
# mawu - nearest hotel: No hotel found
# elne - nearest hotel: Les Jardins de Corneilla
# pyt-yakh - nearest hotel: Сибирь
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# san andres - nearest hotel: Hotel Decameron Isleño
# quelimane - nearest hotel: Mabassa
# mooirivier - nearest hotel: Fountain Hall Guest Farm
# stony plain - nearest hotel: Stony Plain Hotel
# dolores - nearest hotel: Plaza Hotel
# jayapura - nearest hotel: Hotel Jasmine Jayapura
# prince rupert - nearest hotel: Crest Hotel
# aleg - nearest hotel: Hotel Oasis Aleg
# novyy urengoy - nearest hotel: ГазпромТрансгазЮгорск
# homosassa springs - nearest hotel: Hampton Inn - Crystal River
# puerto lempira - nearest hotel: Hotel Yu Baiwan
# bodo - nearest hotel: Zefyr hotell
# sungai penuh - nearest hotel: Hotel Matahari
# mostaganem - nearest hotel: Hôtel Munatec
# acarau - nearest hotel: No hotel found
# rosetta - nearest hotel: No hotel found
# tadine - nearest hotel: Hôtel Nengoné
# sundsvall - nearest hotel: Scandic Sundsvall City
# matoury - nearest hotel: La Marmotte
# sarandi del yi - nearest hotel: No hotel found
# vila velha - nearest hotel: Hotel Prainha
# sainte-suzanne - nearest hotel: No hotel found
# kansanshi - nearest hotel: Paka Lodge
# idah - nearest hotel: No hotel found
# staroleushkovskaya - nearest hotel: База отдыъа "Лесная нимфа"
# antofagasta - nearest hotel: Hotel Colón
# porto murtinho - nearest hotel: Hotel Saladero Cuê
# mukalla - nearest hotel: فندق الجابري
# eagle pass - nearest hotel: Eagle pass inn
# klaksvik - nearest hotel: Hotel Klaksvik
# ust'-ilimsk - nearest hotel: Усть-Илимск
# saint-philippe - nearest hotel: Le Baril
# hobyo - nearest hotel: Iftin Hotel Hobyo
# laguna - nearest hotel: Holiday Inn Express & Suites
# mojkovac - nearest hotel: Hotel Đulović
# happy valley-goose bay - nearest hotel: Hotel North Two
# kletnya - nearest hotel: No hotel found
# nanchong - nearest hotel: 北湖宾馆
# doganyol - nearest hotel: Doğanyol Öğretmen Evi
# phang nga - nearest hotel: Hotel
# rakops - nearest hotel: Rakops River Lodge
# miyoshi - nearest hotel: ビジネスホテル光陽
# levuka - nearest hotel: No hotel found
# faya-largeau - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# ulsteinvik - nearest hotel: Quality Hotel Ulstein
# qaisumah - nearest hotel: No hotel found
# ingeniero jacobacci - nearest hotel: Gran Hotel Argentino
# mary - nearest hotel: No hotel found
# tofol - nearest hotel: Nautilus Resort
# bastogne - nearest hotel: Wagon Léo
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
# guaratuba - nearest hotel: No hotel found
# kavaratti - nearest hotel: No hotel found
# ouani - nearest hotel: Al Amal
# saldanha - nearest hotel: Hoedjesbaai
# enshi - nearest hotel: No hotel found
# kruisfontein - nearest hotel: No hotel found
# pathein - nearest hotel: Taan Taan Ta
# natal - nearest hotel: Natal Palace Hotel
# ataq - nearest hotel: الشارقة بلازا
# celestun - nearest hotel: Hotel Flamingo Playa
# aitape - nearest hotel: No hotel found
# laminusa - nearest hotel: No hotel found
# princeville - nearest hotel: No hotel found
# colachel - nearest hotel: No hotel found
# kalemie - nearest hotel: Hotel du Lac
# kani keli - nearest hotel: Hôtel Le Jardin Maoré
# polyarnyy - nearest hotel: No hotel found
# arkalyk - nearest hotel: Гостиница "Арсенал"
# golfito - nearest hotel: Bahia Marina Golfito Hotel
# quang ngai - nearest hotel: Ngoc Anh
# namibe - nearest hotel: Nelsal Pensao
# mutuali - nearest hotel: No hotel found
# south valley - nearest hotel: Hampton Inn & Suites Albuquerque Airport
# kenai - nearest hotel: Beluga Lookout Hotel
# cascais - nearest hotel: Cascais Hotel
# gostovici - nearest hotel: Kristal
# oriximina - nearest hotel: No hotel found
# paoua - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# margate - nearest hotel: The Reading Rooms
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# illizi - nearest hotel: بوناقة
# san felice circeo - nearest hotel: Centro Ferie Salvatore
# robbah - nearest hotel: No hotel found
# lorena - nearest hotel: Hotel Guarany
# pierre - nearest hotel: Quality Inn
# northam - nearest hotel: Durrant House Hotel
# remire-montjoly - nearest hotel: Complexe Belova
# batamshinskiy - nearest hotel: No hotel found
# leh - nearest hotel: Kang Lha Chen
# vilyuchinsk - nearest hotel: Победа
# ouadda - nearest hotel: No hotel found
# kirensk - nearest hotel: Ивушка
# uliastay - nearest hotel: Болоржин зочид буудал
# dunafoldvar - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# anna regina - nearest hotel: Jaigobin Hotel
# impfondo - nearest hotel: Tropicana
# port saint john's - nearest hotel: Outback Inn
# umm kaddadah - nearest hotel: No hotel found
# ponta delgada - nearest hotel: Hotel Talisman
# waingapu - nearest hotel: HOTEL SANDLEWOOD
# uttarkashi - nearest hotel: Shivalinga
# general acha - nearest hotel: Hotel Patagonia
# nieuw nickerie - nearest hotel: Hotel Pak Hap
# kimbe - nearest hotel: Kimbe Bay Hotel
# puerto baquerizo moreno - nearest hotel: Dory's House
# isla vista - nearest hotel: The Club & Guest House
# lakatoro - nearest hotel: No hotel found
# hami - nearest hotel: Хами
# mengen - nearest hotel: Rebstock
# grantsville - nearest hotel: No hotel found
# bintulu - nearest hotel: Bakun Inn
# goulburn - nearest hotel: Empire Hotel
# kerman - nearest hotel: حافظ
# kasane - nearest hotel: Kasane Travel Lodge
# taro - nearest hotel: Padma Resort Ubud
# khandyga - nearest hotel: Апельсин
# vielha - nearest hotel: Parador de Turisme de Vielha
# gizo - nearest hotel: Gizo Hotel
# gobo - nearest hotel: 旅路旅館
# sal rei - nearest hotel: Hotel Marine Club
# monte argentario - nearest hotel: Belvedere
# chegutu - nearest hotel: Chegutu hotel
# ouesso - nearest hotel: Auberge Nianina
# itaituba - nearest hotel: TG Hotel
# kalaoa - nearest hotel: PACIFIC 19 Kona
# kresttsy - nearest hotel: No hotel found
# paradip garh - nearest hotel: Hotel Sea Pearl
# san julian - nearest hotel: No hotel found
# xinyang - nearest hotel: 德龙太子酒店
# katsuren-haebaru - nearest hotel: No hotel found
# tipasa - nearest hotel: Hôtel Munatec
# madingou - nearest hotel: Résidence Laurel
# wonsan - nearest hotel: 원산호텔
# prado - nearest hotel: Pousada Recanto do Prado
# bondo - nearest hotel: No hotel found
# hannoversch munden - nearest hotel: Alte Windmühle
# golere - nearest hotel: Espace Aduna'm
# poshekhon'ye - nearest hotel: Сога
# balkanabat - nearest hotel: Nebitçi
# deir ez-zor - nearest hotel: فندق السعيد
# la sarre - nearest hotel: Motel le Bivouac
# la huacana - nearest hotel: No hotel found
# pechory - nearest hotel: Печоры Парк
# egilsstadir - nearest hotel: Valaskjálf
# chimoio - nearest hotel: Hotel Amirana
# taiyuan - nearest hotel: 汾酒大厦
# nemuro - nearest hotel: お宿エクハシ
# fort st. john - nearest hotel: Fort St. John Motor Inn
# rupert - nearest hotel: No hotel found
# taulaga - nearest hotel: No hotel found
# kuta - nearest hotel: Ida Hotel Bali
# san sebastian de la gomera - nearest hotel: Hotel Villa Gomera
# usogorsk - nearest hotel: Единственная
# hirara - nearest hotel: 古謝そば屋
# masterton - nearest hotel: Copthorne Hotel Solway Park
# wad rawah - nearest hotel: No hotel found
# sao vicente - nearest hotel: Pousada Vitória
# aldama - nearest hotel: Presas del rey
# tyuratam - nearest hotel: Спутник
# jardin - nearest hotel: Jardín es Tuyo
# meadow lakes - nearest hotel: Best Western Lake Lucille Inn
# sonqor - nearest hotel: No hotel found
# beroroha - nearest hotel: No hotel found
# belle fourche - nearest hotel: Kings Inn
# mossel bay - nearest hotel: Protea Hotel Mossel Bay
# sibolga - nearest hotel: Hotel Prima Indah
# caleta olivia - nearest hotel: Grand Hotel Snack
# qarauyl - nearest hotel: Гомтиница Ер-нур
# solnechnyy - nearest hotel: Заря
# alo - nearest hotel: No hotel found
# ulladulla - nearest hotel: Hotel Marlin
# korla - nearest hotel: Silver Star Hotel
# turuntayevo - nearest hotel: No hotel found
#      City_ID                         City      Lat       Lng  Max Temp  \
# 0          0                       igarka  67.4667   86.5833    252.39
# 1          1                      talnakh  69.4865   88.3972    245.08
# 2          2  edinburgh of the seven seas -37.0676  -12.3116    286.12
# 3          3                  west island -12.1568   96.8225    300.14
# 4          4                      aasiaat  68.7098  -52.8699    269.96
# ..       ...                          ...      ...       ...       ...
# 571      571                   solnechnyy  50.7214  136.6319    267.01
# 572      572                          alo   6.5486    4.2686    299.77
# 573      573                    ulladulla -35.3500  150.4667    289.80
# 574      574                        korla  41.7597   86.1469    280.42
# 575      575                  turuntayevo  52.2000  107.6167    264.69
#
#      Humidity  Cloudiness  Wind Speed Country        Date Hotel name  \
# 0          91         100        5.25      RU  1731348836
# 1          91          29        0.76      RU  1731348837
# 2          81          99        7.58      SH  1731348838
# 3          83         100        5.66      CC  1731348839
# 4          77         100        4.27      GL  1731348840
# ..        ...         ...         ...     ...         ...        ...
# 571        87         100        0.21      RU  1731349501
# 572        85          42        2.80      NG  1731349502
# 573        90          84        2.09      AU  1731349503
# 574        55          84        0.46      CN  1731349504
# 575        93          61        0.56      RU  1731349506
#
#                   Hotel Name
# 0                  Заполярье
# 1                     Талнах
# 2             No hotel found
# 3    Cocos Village Bungalows
# 4                       SØMA
# ..                       ...
# 571                     Заря
# 572           No hotel found
# 573             Hotel Marlin
# 574        Silver Star Hotel
# 575           No hotel found
#
# [576 rows x 12 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)

# %%
hotel_df.head()
# Out:
#           City   latitude   longitude      Hotel Name Country  \
# 0     New York  40.730610  -73.935242       Hotel XYZ     USA
# 1  Los Angeles  34.052235 -118.243683       Hotel ABC     USA
# 2      Chicago  41.878113  -87.629799  No hotel found     USA
#
#                                        hover_message
# 0  City: New York<br>Hotel: Hotel XYZ<br>Country:...
# 1  City: Los Angeles<br>Hotel: Hotel ABC<br>Count...
# 2  City: Chicago<br>Hotel: No hotel found<br>Coun...

# %%
hotel_df = hotel_df.dropna()

# Transform latitude and longitude to float
hotel_df["latitude"] = hotel_df["latitude"].astype(float)
hotel_df["longitude"] = hotel_df["longitude"].astype(float)

# Display sample data
hotel_df.head()
# Out:
#           City   latitude   longitude      Hotel Name Country  \
# 0     New York  40.730610  -73.935242       Hotel XYZ     USA
# 1  Los Angeles  34.052235 -118.243683       Hotel ABC     USA
# 2      Chicago  41.878113  -87.629799  No hotel found     USA
#
#                                        hover_message
# 0  City: New York<br>Hotel: Hotel XYZ<br>Country:...
# 1  City: Los Angeles<br>Hotel: Hotel ABC<br>Count...
# 2  City: Chicago<br>Hotel: No hotel found<br>Coun...

# %%
# %%capture --no-display
hotel_df['hover_message'] = hotel_df.apply(
    lambda row: f"City: {row['City']}<br>Hotel: {row['Hotel Name']}<br>Country: {row['Country']}", axis=1)
hotel_map = hotel_df.hvplot.points(
                               "longitude",
                                "latitude",
                                geo = True,
                                tiles = "OSM",
                                frame_width = 800,
                                frame_height = 600,
                                size = "Hotel Name",
                                scale = 2,
                                color = "City",
                                hover_cols = ['City', 'Hotel Name', 'Country']
)

# Display the map plot
plot.opts(title='Cities and Hotels', width=800, height=600)
# Out:
# :NdOverlay   [Variable]
#    :Scatter   [index]   (value,Hotel Name,City,Country)

# %%
# Ensure 'Lat' and 'Lng' columns are numeric
hotel_df['latitude'] = pd.to_numeric(hotel_df['latitude'], errors='coerce')
hotel_df['longitude'] = pd.to_numeric(hotel_df['longitude'], errors='coerce')

# Drop any rows where 'Lat' or 'Lng' are NaN
hotel_df = hotel_df.dropna(subset=['latitude', 'longitude'])

# Set up hover messages to provide city, hotel, and country details
hotel_df['hover_message'] = hotel_df.apply(
    lambda row: f"City: {row['City']}<br>Hotel: {row['Hotel Name']}<br>Country: {row['Country']}", axis=1
)

# Plot using hvplot with corrected parameters
plot = hotel_df.hvplot.points(
    x='longitude',             # Longitude as x
    y='latitude',             # Latitude as y
    geo=True,            # Enable geospatial plotting
    tiles='OSM',         # Use OpenStreetMap tiles
    frame_width=800,     # Set frame width
    frame_height=600,    # Set frame height
    size=10,             # Use a fixed size for plot markers
    scale=1,             # Adjust size scaling if needed
    color='City',        # Color points by city
    hover_cols=['City', 'Hotel Name', 'Country']  # Add hover columns
)

# Display the map plot
plot.opts(title='Map of Cities with Nearest Hotels', width=800, height=600)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [longitude,latitude]   (City,Hotel Name,Country)
